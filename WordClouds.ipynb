# %%
# Imports
import pandas as pd
import numpy as np
import nltk
import string
import re
import matplotlib.pyplot as plt
from pickle import dump, load

from PIL import Image

# %%
# Read preprocessed csv
url = "https://uom-twitter-sentiment-analysis.s3.us-east-2.amazonaws.com/Lemmatize.csv"
lemmatized_df = pd.read_csv(url)
lemmatized_df.head()
# Out:
#    target                                               text
# 0       0                             ['ahhh', 'hope', 'ok']
# 1       0             ['cool', 'tweet', 'apps', 'razr', '2']
# 2       0  ['know', 'family', 'drama', 'lamehey', 'next',...
# 3       0  ['school', 'email', 'wont', 'open', 'geography...
# 4       0                     ['upper', 'airway', 'problem']

# %%
from wordcloud import WordCloud
# WordCloud
cloud = WordCloud().generate(str(lemmatized_df['text']) )
fig= plt.figure(figsize=(14,14))
plt.imshow(cloud)

# %%
negative_Tweets = lemmatized_df[lemmatized_df.target == 0]

negative_Tweets.head()

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
wc = WordCloud(max_words=50)

cloud =wc.generate(str(negative_Tweets ))
fig= plt.figure(figsize=(14,14))
plt.imshow(cloud)

# %%
positive_Tweets = lemmatized_df[lemmatized_df.target == 1]

positive_Tweets.head()

from wordcloud import WordCloud
wc = WordCloud(max_words=50)

cloud =wc.generate(str(positive_Tweets ))
fig= plt.figure(figsize=(14,14))
plt.imshow(cloud)

# %%
thumbs_up_mask = np.array(Image.open('images/t3.png'))
thumbs_down_mask = np.array(Image.open('images/thumbs_down.png'))
thumbs_up_mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         [  0,   0,   0, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
def multi_color_func(word=None, font_size=None,
                     position=None, orientation=None,
                     font_path=None, random_state=None):
    colors = [[4, 77, 82],
              [25, 74, 85],
              [82, 43, 84],
              [158, 48, 79]]
    rand = random_state.randint(0, len(colors) - 1)
return "hsl({}, {}%, {}%)".format(colors[rand][0], colors[rand][1], colors[rand][2])
# Out:
#   Input In [34]
#     return "hsl({}, {}%, {}%)".format(colors[rand][0], colors[rand][1], colors[rand][2])
#     ^
# SyntaxError: 'return' outside function

# %%
stopwords = set(STOPWORDS)
# mask = np.array(Image.open("../input/input-img/cloud.png"))
wordcloud = WordCloud(random_state = 1,background_color='white', max_words=1000, mask=thumbs_up_mask,\
                      contour_width=3, colormap='tab20b', collocations = False).generate(str(positive_Tweets))
# create image as cloud
# image_colors = ImageColorGenerator(thumbs_up_mask)
plt.figure(figsize=[10,10])
# plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 979.5, 979.5, -0.5)
